# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.metrics import (
    roc_curve, auc,
    precision_recall_curve, average_precision_score,
    confusion_matrix, f1_score, roc_auc_score
)
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras import DPKerasAdamOptimizer
import glob
# Out:
# 2025-05-07 14:14:00.470487: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-07 14:14:00.470530: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-07 14:14:00.492825: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-07 14:14:00.557226: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# File Creation

# %%
os.makedirs("tp_robust_viz", exist_ok=True)
os.makedirs("tp_robust_log", exist_ok=True)

# %% [markdown]
# Plotting Functions

# %%
def plot_avg_history(epochs, avg_metrics, std_metrics, noise_vals):

    os.makedirs(f"tp_robust_viz/{epsilons[idx]}", exist_ok=True)
    plt.figure(figsize=(12, 6))

    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, avg_metrics['loss'], label='Train Loss')
    plt.fill_between(epochs, 
                     np.array(avg_metrics['loss']) - np.array(std_metrics['loss']),
                     np.array(avg_metrics['loss']) + np.array(std_metrics['loss']),
                     alpha=0.2)
    plt.plot(epochs, avg_metrics['val_loss'], label='Val Loss')
    plt.fill_between(epochs, 
                     np.array(avg_metrics['val_loss']) - np.array(std_metrics['val_loss']),
                     np.array(avg_metrics['val_loss']) + np.array(std_metrics['val_loss']),
                     alpha=0.2)
    plt.title("Loss over Epochs")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()

    # Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, avg_metrics['accuracy'], label='Train Accuracy')
    plt.fill_between(epochs, 
                     np.array(avg_metrics['accuracy']) - np.array(std_metrics['accuracy']),
                     np.array(avg_metrics['accuracy']) + np.array(std_metrics['accuracy']),
                     alpha=0.2)
    plt.plot(epochs, avg_metrics['val_accuracy'], label='Val Accuracy')
    plt.fill_between(epochs, 
                     np.array(avg_metrics['val_accuracy']) - np.array(std_metrics['val_accuracy']),
                     np.array(avg_metrics['val_accuracy']) + np.array(std_metrics['val_accuracy']),
                     alpha=0.2)
    plt.title("Accuracy over Epochs")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()

    save_dir = f"tp_robust_viz/{noise_vals[idx]}"
    os.makedirs(save_dir, exist_ok=True)

    # Save plot
    plt.savefig(f"{save_dir}/history_curves.png")
    plt.close()

# %%
def plot_mean_se_with_baseline(mean_se_values, x_values, x_label, y_label, filename,
                                baseline, baseline_label="Baseline"):
    
    os.makedirs("tp_robust_viz", exist_ok=True)

    means = np.array([m for m, se in mean_se_values])
    ses = np.array([se for m, se in mean_se_values])

    # Extend data with baseline
    baseline_mean, baseline_se = baseline
    means = np.append(means, baseline_mean)
    ses = np.append(ses, baseline_se)
    x_all = list(x_values) + [baseline_label]

    x_ticks = np.arange(len(x_all))

    plt.figure(figsize=(10, 5))
    plt.errorbar(x_ticks, means, yerr=ses, fmt='o-', capsize=5,
                 color='steelblue', ecolor='gray', elinewidth=2, marker='o')

    plt.xticks(ticks=x_ticks, labels=x_all, rotation=45)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(f"{y_label} across epsilons with SE and Baseline")
    plt.grid(True)
    plt.tight_layout()

    save_dir = f"tp_robust_viz"
    os.makedirs(save_dir, exist_ok=True)

    # Save plot
    plt.savefig(f"{save_dir}/{filename}.png")
    plt.close()
    
    
    plt.close()

# %%
def plot_confusion_matrix_with_se(conf_matrix, annotations, noise_vals):
    plt.figure(figsize=(6, 5))
    sns.heatmap(conf_matrix, annot=annotations, fmt='', cmap="Blues", cbar=False, square=True,
                xticklabels=['Predicted 0', 'Predicted 1'],
                yticklabels=['Actual 0', 'Actual 1'])

    plt.title(f'Average Confusion Matrix with SE for epsilon {noise_vals[idx]}')
    plt.xlabel('Prediction')
    plt.ylabel('Actual')
    plt.tight_layout()
    save_dir = f"tp_robust_viz/{noise_vals[idx]}"
    os.makedirs(save_dir, exist_ok=True)
    # Save plot
    plt.savefig(f"{save_dir}/avg_confusion_matrix.png")
    plt.close()

    
    plt.close()

# %%
def plot_metric_distribution(values, metric_name, filename, noise_vals):
    mean, ci_lower, ci_upper = np_95ci(values)

    plt.figure(figsize=(8, 5))
    plt.hist(values, bins=15, color='skyblue', edgecolor='black', alpha=0.7)
    plt.axvline(mean, color='red', linestyle='--', label=f'Mean = {mean:.3f}')
    plt.axvline(ci_lower, color='green', linestyle=':', label=f'95% CI Lower = {ci_lower:.3f}')
    plt.axvline(ci_upper, color='green', linestyle=':', label=f'95% CI Upper = {ci_upper:.3f}')
    
    plt.title(f'{metric_name} Distribution with 95% CI')
    plt.xlabel(metric_name)
    plt.ylabel('Frequency')
    plt.legend()
    plt.tight_layout()
    # Ensure directory exists
    save_dir = f"tp_robust_viz/{noise_vals[idx]}"
    os.makedirs(save_dir, exist_ok=True)

    # Save plot
    plt.savefig(f"{save_dir}/{filename}.png")
    plt.close()

# %% [markdown]
# STATS FUNCTIONS

# %%
def np_95ci(data):
    mean = np.mean(data)
    std = np.std(data, ddof=1)  # sample standard deviation
    se = std / np.sqrt(len(data))
    ci_lower = mean - 1.96 * se
    ci_upper = mean + 1.96 * se
    return mean, ci_lower, ci_upper

# %%
def mean_se(values):
    values = np.array(values)
    return np.mean(values), np.std(values, ddof=1) / np.sqrt(len(values))

# %%
def bootstrap(x_train, y_train):
    x_train = pd.DataFrame(x_train)
    y_train = pd.DataFrame(y_train)
    k = len(x_train)
    idx = np.random.choice(k, size = k,  replace = True)
    return x_train.iloc[idx], y_train.iloc[idx]

# %% [markdown]
# Preprocessing Functions

# %%
def data_gen(data, test_size =.2, random_state = 42):
    data_holder = []
        
    X = data.drop(columns=['disease']).values
    y = data['disease'].values

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=test_size, random_state=random_state)
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    X_val = scaler.transform(X_val)

    data_holder.append((X_train, X_test, y_train, y_test, X_val, y_val))

    return data_holder

# %% [markdown]
# Preprocessing

# %%
#TODO: You may need to fix file paths to whatever this is on your cluster
data = pd.read_csv('../data/endometriosis_dataset.csv')
datasets = data_gen(data)

#training hyper paramters
batch_size = 32
delta = 1e-5
l2_norm_clip = 1.0
epsilons = [.001, .01, .1, 1, 10]
noise_vals = [100.0, 99.0, 75.03, 8.3, 1.31]

# %%
noise_vals_2 = [99.0, 8.3]

# %%
noise_vals_3 = [1.31]

# %% [markdown]
# Model Training Functions

# %%
def model_train(data):
    idx = 0

    for noise_multiplier in noise_vals:

        os.makedirs(f"tp_robust_log/{noise_multiplier}", exist_ok=True)
        os.makedirs(f"models_tp_robust/{noise_multiplier}", exist_ok=True)
        
        for i in range(50):

            X_boot, y_boot = bootstrap(data[idx][0], data[idx][2])
            
    
            DP_model = Sequential([
            Dense(512, activation='relu', input_shape=(data[idx][0].shape[1],)),
            Dropout(0.5),
            Dense(128, activation='relu'),
            Dropout(0.5),
            Dense(1, activation='sigmoid')
        ])
            
            dp_optimizer = DPKerasAdamOptimizer(
        l2_norm_clip=l2_norm_clip,
        noise_multiplier=noise_multiplier,
        num_microbatches=batch_size,
        learning_rate=1e-3
    )
            loss_fn = tf.keras.losses.BinaryCrossentropy(
                from_logits=False,
                reduction=tf.keras.losses.Reduction.NONE
            )

            DP_model.compile(
                optimizer=dp_optimizer,
                loss=loss_fn,
                metrics=['accuracy']
            )
        
            csv_logger = tf.keras.callbacks.CSVLogger(f"tp_robust_log/{noise_multiplier}/training_log_tp_{i}.csv", append=True)
            
            checkpoint = tf.keras.callbacks.ModelCheckpoint(
            filepath=f"models_tp_robust/{noise_multiplier}/model_tp_{i}_{{epoch:02d}}.keras",
            save_weights_only=False,
            save_best_only=False,  # Save every epoch
            verbose=1
            )
    
            # Create tf.data.Dataset and ensure all batches are complete
            train_dataset = tf.data.Dataset.from_tensor_slices((X_boot, y_boot))
            train_dataset = train_dataset.shuffle(buffer_size=1024)  # optional
            train_dataset = train_dataset.batch(batch_size, drop_remainder=True)

            val_dataset = tf.data.Dataset.from_tensor_slices((data[idx][4], data[idx][5]))
            val_dataset = val_dataset.batch(batch_size, drop_remainder=True)
            
            # Compute number of full steps (batches)
            steps_per_epoch = len(X_boot) // batch_size
            
            # Then fit the model
            DP_model.fit(
                train_dataset,
                epochs=50,
                steps_per_epoch=steps_per_epoch,
                validation_data=val_dataset,
                callbacks=[csv_logger, checkpoint]
            )

# %%
def model_train_2(data):
    idx = 0

    for noise_multiplier in noise_vals_3:

        os.makedirs(f"tp_robust_log/{noise_multiplier}", exist_ok=True)
        os.makedirs(f"models_tp_robust/{noise_multiplier}", exist_ok=True)
        
        for i in range(50):

            X_boot, y_boot = bootstrap(data[idx][0], data[idx][2])
            
    
            DP_model = Sequential([
            Dense(512, activation='relu', input_shape=(data[idx][0].shape[1],)),
            Dropout(0.5),
            Dense(128, activation='relu'),
            Dropout(0.5),
            Dense(1, activation='sigmoid')
        ])
            
            dp_optimizer = DPKerasAdamOptimizer(
        l2_norm_clip=l2_norm_clip,
        noise_multiplier=noise_multiplier,
        num_microbatches=batch_size,
        learning_rate=1e-3
    )
            loss_fn = tf.keras.losses.BinaryCrossentropy(
                from_logits=False,
                reduction=tf.keras.losses.Reduction.NONE
            )

            DP_model.compile(
                optimizer=dp_optimizer,
                loss=loss_fn,
                metrics=['accuracy']
            )
        
            csv_logger = tf.keras.callbacks.CSVLogger(f"tp_robust_log/{noise_multiplier}/training_log_tp_{i}.csv", append=True)
            
            checkpoint = tf.keras.callbacks.ModelCheckpoint(
            filepath=f"models_tp_robust/{noise_multiplier}/model_tp_{i}_{{epoch:02d}}.keras",
            save_weights_only=False,
            save_best_only=False,  # Save every epoch
            verbose=1
            )
    
            # Create tf.data.Dataset and ensure all batches are complete
            train_dataset = tf.data.Dataset.from_tensor_slices((X_boot, y_boot))
            train_dataset = train_dataset.shuffle(buffer_size=1024)  # optional
            train_dataset = train_dataset.batch(batch_size, drop_remainder=True)

            val_dataset = tf.data.Dataset.from_tensor_slices((data[idx][4], data[idx][5]))
            val_dataset = val_dataset.batch(batch_size, drop_remainder=True)
            
            # Compute number of full steps (batches)
            steps_per_epoch = len(X_boot) // batch_size
            
            # Then fit the model
            DP_model.fit(
                train_dataset,
                epochs=50,
                steps_per_epoch=steps_per_epoch,
                validation_data=val_dataset,
                callbacks=[csv_logger, checkpoint]
            )

# %% [markdown]
# Model Training

# %%
model_train(datasets)
# Out:
# KeyboardInterrupt

# %%
model_train_2(datasets)
# Out:
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 1.2503 - accuracy: 0.5223
# Epoch 1: saving model to models_tp_robust/1.31/model_tp_0_01.keras
# 7/7 [==============================] - 2s 146ms/step - loss: 1.2503 - accuracy: 0.5223 - val_loss: 0.9177 - val_accuracy: 0.4375
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1271 - accuracy: 0.5446
# Epoch 2: saving model to models_tp_robust/1.31/model_tp_0_02.keras
# 7/7 [==============================] - 1s 140ms/step - loss: 1.1271 - accuracy: 0.5446 - val_loss: 0.8432 - val_accuracy: 0.5000
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1379 - accuracy: 0.5670
# Epoch 3: saving model to models_tp_robust/1.31/model_tp_0_03.keras
# 7/7 [==============================] - 1s 138ms/step - loss: 1.1379 - accuracy: 0.5670 - val_loss: 0.7761 - val_accuracy: 0.5938
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1204 - accuracy: 0.5982
# Epoch 4: saving model to models_tp_robust/1.31/model_tp_0_04.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 1.1204 - accuracy: 0.5982 - val_loss: 0.7327 - val_accuracy: 0.5938
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 1.2128 - accuracy: 0.5759
# Epoch 5: saving model to models_tp_robust/1.31/model_tp_0_05.keras
# 7/7 [==============================] - 1s 142ms/step - loss: 1.2128 - accuracy: 0.5759 - val_loss: 0.6720 - val_accuracy: 0.6250
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0858 - accuracy: 0.5982
# Epoch 6: saving model to models_tp_robust/1.31/model_tp_0_06.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 1.0858 - accuracy: 0.5982 - val_loss: 0.6105 - val_accuracy: 0.6875
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 1.2107 - accuracy: 0.5759
# Epoch 7: saving model to models_tp_robust/1.31/model_tp_0_07.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 1.2107 - accuracy: 0.5759 - val_loss: 0.5616 - val_accuracy: 0.7812
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1139 - accuracy: 0.6295
# Epoch 8: saving model to models_tp_robust/1.31/model_tp_0_08.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 1.1139 - accuracy: 0.6295 - val_loss: 0.5422 - val_accuracy: 0.7812
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8131 - accuracy: 0.7500
# Epoch 9: saving model to models_tp_robust/1.31/model_tp_0_09.keras
# 7/7 [==============================] - 1s 139ms/step - loss: 0.8131 - accuracy: 0.7500 - val_loss: 0.5308 - val_accuracy: 0.7812
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0457 - accuracy: 0.6473
# Epoch 10: saving model to models_tp_robust/1.31/model_tp_0_10.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 1.0457 - accuracy: 0.6473 - val_loss: 0.5259 - val_accuracy: 0.8125
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8400 - accuracy: 0.7455
# Epoch 11: saving model to models_tp_robust/1.31/model_tp_0_11.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.8400 - accuracy: 0.7455 - val_loss: 0.5097 - val_accuracy: 0.8125
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8925 - accuracy: 0.7321
# Epoch 12: saving model to models_tp_robust/1.31/model_tp_0_12.keras
# 7/7 [==============================] - 1s 138ms/step - loss: 0.8925 - accuracy: 0.7321 - val_loss: 0.5035 - val_accuracy: 0.8438
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8935 - accuracy: 0.7321
# Epoch 13: saving model to models_tp_robust/1.31/model_tp_0_13.keras
# 7/7 [==============================] - 1s 138ms/step - loss: 0.8935 - accuracy: 0.7321 - val_loss: 0.5149 - val_accuracy: 0.8438
# Epoch 14/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8601 - accuracy: 0.7500
# Epoch 14: saving model to models_tp_robust/1.31/model_tp_0_14.keras
# 7/7 [==============================] - 1s 132ms/step - loss: 0.8601 - accuracy: 0.7500 - val_loss: 0.5360 - val_accuracy: 0.8438
# Epoch 15/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9293 - accuracy: 0.7500
# Epoch 15: saving model to models_tp_robust/1.31/model_tp_0_15.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.9293 - accuracy: 0.7500 - val_loss: 0.5750 - val_accuracy: 0.8125
# Epoch 16/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7126 - accuracy: 0.7902
# Epoch 16: saving model to models_tp_robust/1.31/model_tp_0_16.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.7126 - accuracy: 0.7902 - val_loss: 0.6540 - val_accuracy: 0.7812
# Epoch 17/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9131 - accuracy: 0.7232
# Epoch 17: saving model to models_tp_robust/1.31/model_tp_0_17.keras
# 7/7 [==============================] - 1s 143ms/step - loss: 0.9131 - accuracy: 0.7232 - val_loss: 0.7238 - val_accuracy: 0.7812
# Epoch 18/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7770 - accuracy: 0.7634
# Epoch 18: saving model to models_tp_robust/1.31/model_tp_0_18.keras
# 7/7 [==============================] - 1s 148ms/step - loss: 0.7770 - accuracy: 0.7634 - val_loss: 0.7688 - val_accuracy: 0.7812
# Epoch 19/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7474 - accuracy: 0.7946
# Epoch 19: saving model to models_tp_robust/1.31/model_tp_0_19.keras
# 7/7 [==============================] - 1s 139ms/step - loss: 0.7474 - accuracy: 0.7946 - val_loss: 0.8230 - val_accuracy: 0.7812
# Epoch 20/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7895 - accuracy: 0.8036
# Epoch 20: saving model to models_tp_robust/1.31/model_tp_0_20.keras
# 7/7 [==============================] - 1s 156ms/step - loss: 0.7895 - accuracy: 0.8036 - val_loss: 0.8714 - val_accuracy: 0.7812
# Epoch 21/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8289 - accuracy: 0.7768
# Epoch 21: saving model to models_tp_robust/1.31/model_tp_0_21.keras
# 7/7 [==============================] - 1s 132ms/step - loss: 0.8289 - accuracy: 0.7768 - val_loss: 0.9189 - val_accuracy: 0.7812
# Epoch 22/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9744 - accuracy: 0.7545
# Epoch 22: saving model to models_tp_robust/1.31/model_tp_0_22.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.9744 - accuracy: 0.7545 - val_loss: 0.9452 - val_accuracy: 0.7812
# Epoch 23/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7488 - accuracy: 0.7902
# Epoch 23: saving model to models_tp_robust/1.31/model_tp_0_23.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.7488 - accuracy: 0.7902 - val_loss: 0.9801 - val_accuracy: 0.7812
# Epoch 24/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7346 - accuracy: 0.8080
# Epoch 24: saving model to models_tp_robust/1.31/model_tp_0_24.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.7346 - accuracy: 0.8080 - val_loss: 1.0298 - val_accuracy: 0.7812
# Epoch 25/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8484 - accuracy: 0.7500
# Epoch 25: saving model to models_tp_robust/1.31/model_tp_0_25.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.8484 - accuracy: 0.7500 - val_loss: 1.0642 - val_accuracy: 0.7812
# Epoch 26/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9225 - accuracy: 0.7634
# Epoch 26: saving model to models_tp_robust/1.31/model_tp_0_26.keras
# 7/7 [==============================] - 1s 139ms/step - loss: 0.9225 - accuracy: 0.7634 - val_loss: 1.0945 - val_accuracy: 0.7812
# Epoch 27/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7110 - accuracy: 0.8214
# Epoch 27: saving model to models_tp_robust/1.31/model_tp_0_27.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.7110 - accuracy: 0.8214 - val_loss: 1.1204 - val_accuracy: 0.7812
# Epoch 28/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8585 - accuracy: 0.7857
# Epoch 28: saving model to models_tp_robust/1.31/model_tp_0_28.keras
# 7/7 [==============================] - 1s 132ms/step - loss: 0.8585 - accuracy: 0.7857 - val_loss: 1.1268 - val_accuracy: 0.7812
# Epoch 29/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6497 - accuracy: 0.8259
# Epoch 29: saving model to models_tp_robust/1.31/model_tp_0_29.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.6497 - accuracy: 0.8259 - val_loss: 1.1580 - val_accuracy: 0.7812
# Epoch 30/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7161 - accuracy: 0.8080
# Epoch 30: saving model to models_tp_robust/1.31/model_tp_0_30.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.7161 - accuracy: 0.8080 - val_loss: 1.2046 - val_accuracy: 0.7812
# Epoch 31/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0392 - accuracy: 0.7812
# Epoch 31: saving model to models_tp_robust/1.31/model_tp_0_31.keras
# 7/7 [==============================] - 1s 140ms/step - loss: 1.0392 - accuracy: 0.7812 - val_loss: 1.2510 - val_accuracy: 0.7812
# Epoch 32/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7189 - accuracy: 0.8214
# Epoch 32: saving model to models_tp_robust/1.31/model_tp_0_32.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.7189 - accuracy: 0.8214 - val_loss: 1.2998 - val_accuracy: 0.7812
# Epoch 33/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7973 - accuracy: 0.8438
# Epoch 33: saving model to models_tp_robust/1.31/model_tp_0_33.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.7973 - accuracy: 0.8438 - val_loss: 1.3596 - val_accuracy: 0.7812
# Epoch 34/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0690 - accuracy: 0.7857
# Epoch 34: saving model to models_tp_robust/1.31/model_tp_0_34.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 1.0690 - accuracy: 0.7857 - val_loss: 1.3962 - val_accuracy: 0.7812
# Epoch 35/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8595 - accuracy: 0.7902
# Epoch 35: saving model to models_tp_robust/1.31/model_tp_0_35.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.8595 - accuracy: 0.7902 - val_loss: 1.4456 - val_accuracy: 0.7812
# Epoch 36/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8252 - accuracy: 0.8036
# Epoch 36: saving model to models_tp_robust/1.31/model_tp_0_36.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.8252 - accuracy: 0.8036 - val_loss: 1.4915 - val_accuracy: 0.7812
# Epoch 37/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0788 - accuracy: 0.7946
# Epoch 37: saving model to models_tp_robust/1.31/model_tp_0_37.keras
# 7/7 [==============================] - 1s 141ms/step - loss: 1.0788 - accuracy: 0.7946 - val_loss: 1.5219 - val_accuracy: 0.7812
# Epoch 38/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8604 - accuracy: 0.8616
# Epoch 38: saving model to models_tp_robust/1.31/model_tp_0_38.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.8604 - accuracy: 0.8616 - val_loss: 1.5391 - val_accuracy: 0.7812
# Epoch 39/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0249 - accuracy: 0.7812
# Epoch 39: saving model to models_tp_robust/1.31/model_tp_0_39.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 1.0249 - accuracy: 0.7812 - val_loss: 1.5908 - val_accuracy: 0.7812
# Epoch 40/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0580 - accuracy: 0.8214
# Epoch 40: saving model to models_tp_robust/1.31/model_tp_0_40.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 1.0580 - accuracy: 0.8214 - val_loss: 1.6395 - val_accuracy: 0.7812
# Epoch 41/50
# 7/7 [==============================] - ETA: 0s - loss: 1.2224 - accuracy: 0.7768
# Epoch 41: saving model to models_tp_robust/1.31/model_tp_0_41.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 1.2224 - accuracy: 0.7768 - val_loss: 1.6182 - val_accuracy: 0.7812
# Epoch 42/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8805 - accuracy: 0.8393
# Epoch 42: saving model to models_tp_robust/1.31/model_tp_0_42.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.8805 - accuracy: 0.8393 - val_loss: 1.5580 - val_accuracy: 0.7812
# Epoch 43/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0456 - accuracy: 0.8036
# Epoch 43: saving model to models_tp_robust/1.31/model_tp_0_43.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 1.0456 - accuracy: 0.8036 - val_loss: 1.5053 - val_accuracy: 0.7812
# Epoch 44/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0064 - accuracy: 0.8214
# Epoch 44: saving model to models_tp_robust/1.31/model_tp_0_44.keras
# 7/7 [==============================] - 1s 141ms/step - loss: 1.0064 - accuracy: 0.8214 - val_loss: 1.5022 - val_accuracy: 0.7812
# Epoch 45/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1023 - accuracy: 0.8036
# Epoch 45: saving model to models_tp_robust/1.31/model_tp_0_45.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 1.1023 - accuracy: 0.8036 - val_loss: 1.5338 - val_accuracy: 0.7812
# Epoch 46/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8918 - accuracy: 0.8214
# Epoch 46: saving model to models_tp_robust/1.31/model_tp_0_46.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.8918 - accuracy: 0.8214 - val_loss: 1.5648 - val_accuracy: 0.7812
# Epoch 47/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8799 - accuracy: 0.8304
# Epoch 47: saving model to models_tp_robust/1.31/model_tp_0_47.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.8799 - accuracy: 0.8304 - val_loss: 1.6069 - val_accuracy: 0.7812
# Epoch 48/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9212 - accuracy: 0.8214
# Epoch 48: saving model to models_tp_robust/1.31/model_tp_0_48.keras
# 7/7 [==============================] - 1s 131ms/step - loss: 0.9212 - accuracy: 0.8214 - val_loss: 1.6376 - val_accuracy: 0.7812
# Epoch 49/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7398 - accuracy: 0.8393
# Epoch 49: saving model to models_tp_robust/1.31/model_tp_0_49.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.7398 - accuracy: 0.8393 - val_loss: 1.6449 - val_accuracy: 0.7812
# Epoch 50/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8337 - accuracy: 0.8170
# Epoch 50: saving model to models_tp_robust/1.31/model_tp_0_50.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.8337 - accuracy: 0.8170 - val_loss: 1.6392 - val_accuracy: 0.7812
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7108 - accuracy: 0.6875
# Epoch 1: saving model to models_tp_robust/1.31/model_tp_1_01.keras
# 7/7 [==============================] - 2s 148ms/step - loss: 0.7108 - accuracy: 0.6875 - val_loss: 0.5824 - val_accuracy: 0.7812
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8889 - accuracy: 0.6473
# Epoch 2: saving model to models_tp_robust/1.31/model_tp_1_02.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.8889 - accuracy: 0.6473 - val_loss: 0.5923 - val_accuracy: 0.7812
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7767 - accuracy: 0.6786
# Epoch 3: saving model to models_tp_robust/1.31/model_tp_1_03.keras
# 7/7 [==============================] - 1s 138ms/step - loss: 0.7767 - accuracy: 0.6786 - val_loss: 0.6043 - val_accuracy: 0.7812
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6513 - accuracy: 0.7232
# Epoch 4: saving model to models_tp_robust/1.31/model_tp_1_04.keras
# 7/7 [==============================] - 1s 141ms/step - loss: 0.6513 - accuracy: 0.7232 - val_loss: 0.6061 - val_accuracy: 0.7812
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6991 - accuracy: 0.7589
# Epoch 5: saving model to models_tp_robust/1.31/model_tp_1_05.keras
# 7/7 [==============================] - 1s 140ms/step - loss: 0.6991 - accuracy: 0.7589 - val_loss: 0.5947 - val_accuracy: 0.7812
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.7500
# Epoch 6: saving model to models_tp_robust/1.31/model_tp_1_06.keras
# 7/7 [==============================] - 1s 138ms/step - loss: 0.6927 - accuracy: 0.7500 - val_loss: 0.5804 - val_accuracy: 0.7812
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7119 - accuracy: 0.7411
# Epoch 7: saving model to models_tp_robust/1.31/model_tp_1_07.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.7119 - accuracy: 0.7411 - val_loss: 0.5786 - val_accuracy: 0.7812
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8177 - accuracy: 0.7366
# Epoch 8: saving model to models_tp_robust/1.31/model_tp_1_08.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.8177 - accuracy: 0.7366 - val_loss: 0.5854 - val_accuracy: 0.7812
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6560 - accuracy: 0.7946
# Epoch 9: saving model to models_tp_robust/1.31/model_tp_1_09.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.6560 - accuracy: 0.7946 - val_loss: 0.5801 - val_accuracy: 0.7812
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8925 - accuracy: 0.7277
# Epoch 10: saving model to models_tp_robust/1.31/model_tp_1_10.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.8925 - accuracy: 0.7277 - val_loss: 0.5787 - val_accuracy: 0.7812
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6683 - accuracy: 0.7723
# Epoch 11: saving model to models_tp_robust/1.31/model_tp_1_11.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.6683 - accuracy: 0.7723 - val_loss: 0.5639 - val_accuracy: 0.7812
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7397 - accuracy: 0.7321
# Epoch 12: saving model to models_tp_robust/1.31/model_tp_1_12.keras
# 7/7 [==============================] - 1s 138ms/step - loss: 0.7397 - accuracy: 0.7321 - val_loss: 0.5584 - val_accuracy: 0.8125
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6606 - accuracy: 0.7500
# Epoch 13: saving model to models_tp_robust/1.31/model_tp_1_13.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.6606 - accuracy: 0.7500 - val_loss: 0.5646 - val_accuracy: 0.8125
# Epoch 14/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7062 - accuracy: 0.7634
# Epoch 14: saving model to models_tp_robust/1.31/model_tp_1_14.keras
# 7/7 [==============================] - 1s 139ms/step - loss: 0.7062 - accuracy: 0.7634 - val_loss: 0.5558 - val_accuracy: 0.7812
# Epoch 15/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.7812
# Epoch 15: saving model to models_tp_robust/1.31/model_tp_1_15.keras
# 7/7 [==============================] - 1s 138ms/step - loss: 0.6926 - accuracy: 0.7812 - val_loss: 0.5574 - val_accuracy: 0.7812
# Epoch 16/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6026 - accuracy: 0.7723
# Epoch 16: saving model to models_tp_robust/1.31/model_tp_1_16.keras
# 7/7 [==============================] - 1s 139ms/step - loss: 0.6026 - accuracy: 0.7723 - val_loss: 0.5832 - val_accuracy: 0.7812
# Epoch 17/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0541 - accuracy: 0.7589
# Epoch 17: saving model to models_tp_robust/1.31/model_tp_1_17.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 1.0541 - accuracy: 0.7589 - val_loss: 0.6221 - val_accuracy: 0.7812
# Epoch 18/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6960 - accuracy: 0.7946
# Epoch 18: saving model to models_tp_robust/1.31/model_tp_1_18.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.6960 - accuracy: 0.7946 - val_loss: 0.6565 - val_accuracy: 0.7812
# Epoch 19/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6173 - accuracy: 0.8304
# Epoch 19: saving model to models_tp_robust/1.31/model_tp_1_19.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.6173 - accuracy: 0.8304 - val_loss: 0.7264 - val_accuracy: 0.7812
# Epoch 20/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7149 - accuracy: 0.7991
# Epoch 20: saving model to models_tp_robust/1.31/model_tp_1_20.keras
# 7/7 [==============================] - 1s 140ms/step - loss: 0.7149 - accuracy: 0.7991 - val_loss: 0.7813 - val_accuracy: 0.7812
# Epoch 21/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7786 - accuracy: 0.8348
# Epoch 21: saving model to models_tp_robust/1.31/model_tp_1_21.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.7786 - accuracy: 0.8348 - val_loss: 0.8406 - val_accuracy: 0.7812
# Epoch 22/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6686 - accuracy: 0.8170
# Epoch 22: saving model to models_tp_robust/1.31/model_tp_1_22.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.6686 - accuracy: 0.8170 - val_loss: 0.8941 - val_accuracy: 0.7812
# Epoch 23/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7874 - accuracy: 0.8482
# Epoch 23: saving model to models_tp_robust/1.31/model_tp_1_23.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.7874 - accuracy: 0.8482 - val_loss: 0.9180 - val_accuracy: 0.7812
# Epoch 24/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7043 - accuracy: 0.8304
# Epoch 24: saving model to models_tp_robust/1.31/model_tp_1_24.keras
# 7/7 [==============================] - 1s 141ms/step - loss: 0.7043 - accuracy: 0.8304 - val_loss: 0.9239 - val_accuracy: 0.7812
# Epoch 25/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6187 - accuracy: 0.8348
# Epoch 25: saving model to models_tp_robust/1.31/model_tp_1_25.keras
# 7/7 [==============================] - 1s 139ms/step - loss: 0.6187 - accuracy: 0.8348 - val_loss: 0.9634 - val_accuracy: 0.7812
# Epoch 26/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6158 - accuracy: 0.8616
# Epoch 26: saving model to models_tp_robust/1.31/model_tp_1_26.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.6158 - accuracy: 0.8616 - val_loss: 1.0003 - val_accuracy: 0.7812
# Epoch 27/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6808 - accuracy: 0.8438
# Epoch 27: saving model to models_tp_robust/1.31/model_tp_1_27.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.6808 - accuracy: 0.8438 - val_loss: 1.0309 - val_accuracy: 0.7812
# Epoch 28/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6007 - accuracy: 0.8571
# Epoch 28: saving model to models_tp_robust/1.31/model_tp_1_28.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.6007 - accuracy: 0.8571 - val_loss: 1.0690 - val_accuracy: 0.7812
# Epoch 29/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6906 - accuracy: 0.8661
# Epoch 29: saving model to models_tp_robust/1.31/model_tp_1_29.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.6906 - accuracy: 0.8661 - val_loss: 1.1228 - val_accuracy: 0.7812
# Epoch 30/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7305 - accuracy: 0.8571
# Epoch 30: saving model to models_tp_robust/1.31/model_tp_1_30.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.7305 - accuracy: 0.8571 - val_loss: 1.1685 - val_accuracy: 0.7812
# Epoch 31/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6419 - accuracy: 0.8839
# Epoch 31: saving model to models_tp_robust/1.31/model_tp_1_31.keras
# 7/7 [==============================] - 1s 139ms/step - loss: 0.6419 - accuracy: 0.8839 - val_loss: 1.2129 - val_accuracy: 0.7812
# Epoch 32/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6032 - accuracy: 0.8527
# Epoch 32: saving model to models_tp_robust/1.31/model_tp_1_32.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.6032 - accuracy: 0.8527 - val_loss: 1.2394 - val_accuracy: 0.7812
# Epoch 33/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7422 - accuracy: 0.8527
# Epoch 33: saving model to models_tp_robust/1.31/model_tp_1_33.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.7422 - accuracy: 0.8527 - val_loss: 1.2647 - val_accuracy: 0.7812
# Epoch 34/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6875 - accuracy: 0.8527
# Epoch 34: saving model to models_tp_robust/1.31/model_tp_1_34.keras
# 7/7 [==============================] - 1s 142ms/step - loss: 0.6875 - accuracy: 0.8527 - val_loss: 1.2862 - val_accuracy: 0.7812
# Epoch 35/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8856 - accuracy: 0.8393
# Epoch 35: saving model to models_tp_robust/1.31/model_tp_1_35.keras
# 7/7 [==============================] - 1s 141ms/step - loss: 0.8856 - accuracy: 0.8393 - val_loss: 1.2899 - val_accuracy: 0.7812
# Epoch 36/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6478 - accuracy: 0.8616
# Epoch 36: saving model to models_tp_robust/1.31/model_tp_1_36.keras
# 7/7 [==============================] - 1s 142ms/step - loss: 0.6478 - accuracy: 0.8616 - val_loss: 1.3211 - val_accuracy: 0.7812
# Epoch 37/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7971 - accuracy: 0.8750
# Epoch 37: saving model to models_tp_robust/1.31/model_tp_1_37.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.7971 - accuracy: 0.8750 - val_loss: 1.3584 - val_accuracy: 0.7812
# Epoch 38/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0828 - accuracy: 0.8438
# Epoch 38: saving model to models_tp_robust/1.31/model_tp_1_38.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 1.0828 - accuracy: 0.8438 - val_loss: 1.3912 - val_accuracy: 0.7812
# Epoch 39/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8351 - accuracy: 0.8661
# Epoch 39: saving model to models_tp_robust/1.31/model_tp_1_39.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.8351 - accuracy: 0.8661 - val_loss: 1.4071 - val_accuracy: 0.7812
# Epoch 40/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6260 - accuracy: 0.8571
# Epoch 40: saving model to models_tp_robust/1.31/model_tp_1_40.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.6260 - accuracy: 0.8571 - val_loss: 1.4021 - val_accuracy: 0.7812
# Epoch 41/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8160 - accuracy: 0.8616
# Epoch 41: saving model to models_tp_robust/1.31/model_tp_1_41.keras
# 7/7 [==============================] - 1s 131ms/step - loss: 0.8160 - accuracy: 0.8616 - val_loss: 1.3993 - val_accuracy: 0.7812
# Epoch 42/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8819 - accuracy: 0.8705
# Epoch 42: saving model to models_tp_robust/1.31/model_tp_1_42.keras
# 7/7 [==============================] - 1s 132ms/step - loss: 0.8819 - accuracy: 0.8705 - val_loss: 1.4029 - val_accuracy: 0.7812
# Epoch 43/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0298 - accuracy: 0.8259
# Epoch 43: saving model to models_tp_robust/1.31/model_tp_1_43.keras
# 7/7 [==============================] - 1s 132ms/step - loss: 1.0298 - accuracy: 0.8259 - val_loss: 1.3932 - val_accuracy: 0.7812
# Epoch 44/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5920 - accuracy: 0.8705
# Epoch 44: saving model to models_tp_robust/1.31/model_tp_1_44.keras
# 7/7 [==============================] - 1s 142ms/step - loss: 0.5920 - accuracy: 0.8705 - val_loss: 1.3911 - val_accuracy: 0.7812
# Epoch 45/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7337 - accuracy: 0.8750
# Epoch 45: saving model to models_tp_robust/1.31/model_tp_1_45.keras
# 7/7 [==============================] - 1s 140ms/step - loss: 0.7337 - accuracy: 0.8750 - val_loss: 1.4150 - val_accuracy: 0.7812
# Epoch 46/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8039 - accuracy: 0.8259
# Epoch 46: saving model to models_tp_robust/1.31/model_tp_1_46.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.8039 - accuracy: 0.8259 - val_loss: 1.4216 - val_accuracy: 0.7812
# Epoch 47/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6943 - accuracy: 0.8571
# Epoch 47: saving model to models_tp_robust/1.31/model_tp_1_47.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.6943 - accuracy: 0.8571 - val_loss: 1.4199 - val_accuracy: 0.7812
# Epoch 48/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6283 - accuracy: 0.8884
# Epoch 48: saving model to models_tp_robust/1.31/model_tp_1_48.keras
# 7/7 [==============================] - 1s 140ms/step - loss: 0.6283 - accuracy: 0.8884 - val_loss: 1.4258 - val_accuracy: 0.7812
# Epoch 49/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6748 - accuracy: 0.8527
# Epoch 49: saving model to models_tp_robust/1.31/model_tp_1_49.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.6748 - accuracy: 0.8527 - val_loss: 1.4253 - val_accuracy: 0.7812
# Epoch 50/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9511 - accuracy: 0.8616
# Epoch 50: saving model to models_tp_robust/1.31/model_tp_1_50.keras
# 7/7 [==============================] - 1s 142ms/step - loss: 0.9511 - accuracy: 0.8616 - val_loss: 1.4549 - val_accuracy: 0.7812
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7425 - accuracy: 0.6473
# Epoch 1: saving model to models_tp_robust/1.31/model_tp_2_01.keras
# 7/7 [==============================] - 2s 154ms/step - loss: 0.7425 - accuracy: 0.6473 - val_loss: 0.5541 - val_accuracy: 0.6875
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7969 - accuracy: 0.6741
# Epoch 2: saving model to models_tp_robust/1.31/model_tp_2_02.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.7969 - accuracy: 0.6741 - val_loss: 0.5356 - val_accuracy: 0.6875
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7394 - accuracy: 0.7143
# Epoch 3: saving model to models_tp_robust/1.31/model_tp_2_03.keras
# 7/7 [==============================] - 1s 142ms/step - loss: 0.7394 - accuracy: 0.7143 - val_loss: 0.5461 - val_accuracy: 0.7188
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7021 - accuracy: 0.7098
# Epoch 4: saving model to models_tp_robust/1.31/model_tp_2_04.keras
# 7/7 [==============================] - 1s 140ms/step - loss: 0.7021 - accuracy: 0.7098 - val_loss: 0.5535 - val_accuracy: 0.6875
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7788 - accuracy: 0.7143
# Epoch 5: saving model to models_tp_robust/1.31/model_tp_2_05.keras
# 7/7 [==============================] - 1s 141ms/step - loss: 0.7788 - accuracy: 0.7143 - val_loss: 0.5500 - val_accuracy: 0.6875
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8165 - accuracy: 0.7232
# Epoch 6: saving model to models_tp_robust/1.31/model_tp_2_06.keras
# 7/7 [==============================] - 1s 139ms/step - loss: 0.8165 - accuracy: 0.7232 - val_loss: 0.5353 - val_accuracy: 0.6562
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6760 - accuracy: 0.7500
# Epoch 7: saving model to models_tp_robust/1.31/model_tp_2_07.keras
# 7/7 [==============================] - 1s 145ms/step - loss: 0.6760 - accuracy: 0.7500 - val_loss: 0.5226 - val_accuracy: 0.6875
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.7634
# Epoch 8: saving model to models_tp_robust/1.31/model_tp_2_08.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.6926 - accuracy: 0.7634 - val_loss: 0.5190 - val_accuracy: 0.6875
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8169 - accuracy: 0.7634
# Epoch 9: saving model to models_tp_robust/1.31/model_tp_2_09.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.8169 - accuracy: 0.7634 - val_loss: 0.5196 - val_accuracy: 0.6875
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6394 - accuracy: 0.7902
# Epoch 10: saving model to models_tp_robust/1.31/model_tp_2_10.keras
# 7/7 [==============================] - 1s 141ms/step - loss: 0.6394 - accuracy: 0.7902 - val_loss: 0.5226 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6403 - accuracy: 0.7723
# Epoch 11: saving model to models_tp_robust/1.31/model_tp_2_11.keras
# 7/7 [==============================] - 1s 141ms/step - loss: 0.6403 - accuracy: 0.7723 - val_loss: 0.5169 - val_accuracy: 0.7188
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7837 - accuracy: 0.7455
# Epoch 12: saving model to models_tp_robust/1.31/model_tp_2_12.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.7837 - accuracy: 0.7455 - val_loss: 0.5404 - val_accuracy: 0.7188
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.7366
# Epoch 13: saving model to models_tp_robust/1.31/model_tp_2_13.keras
# 7/7 [==============================] - 1s 141ms/step - loss: 0.6931 - accuracy: 0.7366 - val_loss: 0.5547 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6121 - accuracy: 0.7902
# Epoch 14: saving model to models_tp_robust/1.31/model_tp_2_14.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.6121 - accuracy: 0.7902 - val_loss: 0.5781 - val_accuracy: 0.7500
# Epoch 15/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6499 - accuracy: 0.8036
# Epoch 15: saving model to models_tp_robust/1.31/model_tp_2_15.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.6499 - accuracy: 0.8036 - val_loss: 0.6016 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7139 - accuracy: 0.7902
# Epoch 16: saving model to models_tp_robust/1.31/model_tp_2_16.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.7139 - accuracy: 0.7902 - val_loss: 0.6215 - val_accuracy: 0.7500
# Epoch 17/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5962 - accuracy: 0.8036
# Epoch 17: saving model to models_tp_robust/1.31/model_tp_2_17.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.5962 - accuracy: 0.8036 - val_loss: 0.6329 - val_accuracy: 0.7500
# Epoch 18/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7287 - accuracy: 0.8170
# Epoch 18: saving model to models_tp_robust/1.31/model_tp_2_18.keras
# 7/7 [==============================] - 1s 138ms/step - loss: 0.7287 - accuracy: 0.8170 - val_loss: 0.6194 - val_accuracy: 0.7500
# Epoch 19/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8241 - accuracy: 0.7768
# Epoch 19: saving model to models_tp_robust/1.31/model_tp_2_19.keras
# 7/7 [==============================] - 1s 139ms/step - loss: 0.8241 - accuracy: 0.7768 - val_loss: 0.6270 - val_accuracy: 0.7500
# Epoch 20/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7424 - accuracy: 0.7902
# Epoch 20: saving model to models_tp_robust/1.31/model_tp_2_20.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.7424 - accuracy: 0.7902 - val_loss: 0.6273 - val_accuracy: 0.7500
# Epoch 21/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6366 - accuracy: 0.8348
# Epoch 21: saving model to models_tp_robust/1.31/model_tp_2_21.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.6366 - accuracy: 0.8348 - val_loss: 0.6373 - val_accuracy: 0.7500
# Epoch 22/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.8438
# Epoch 22: saving model to models_tp_robust/1.31/model_tp_2_22.keras
# 7/7 [==============================] - 1s 142ms/step - loss: 0.6902 - accuracy: 0.8438 - val_loss: 0.6685 - val_accuracy: 0.7500
# Epoch 23/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5421 - accuracy: 0.8259
# Epoch 23: saving model to models_tp_robust/1.31/model_tp_2_23.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.5421 - accuracy: 0.8259 - val_loss: 0.6854 - val_accuracy: 0.7500
# Epoch 24/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9216 - accuracy: 0.8170
# Epoch 24: saving model to models_tp_robust/1.31/model_tp_2_24.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.9216 - accuracy: 0.8170 - val_loss: 0.7017 - val_accuracy: 0.7500
# Epoch 25/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5869 - accuracy: 0.8482
# Epoch 25: saving model to models_tp_robust/1.31/model_tp_2_25.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.5869 - accuracy: 0.8482 - val_loss: 0.7230 - val_accuracy: 0.7812
# Epoch 26/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6784 - accuracy: 0.8527
# Epoch 26: saving model to models_tp_robust/1.31/model_tp_2_26.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.6784 - accuracy: 0.8527 - val_loss: 0.7266 - val_accuracy: 0.7812
# Epoch 27/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8025 - accuracy: 0.8170
# Epoch 27: saving model to models_tp_robust/1.31/model_tp_2_27.keras
# 7/7 [==============================] - 1s 139ms/step - loss: 0.8025 - accuracy: 0.8170 - val_loss: 0.7544 - val_accuracy: 0.7500
# Epoch 28/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8199 - accuracy: 0.8036
# Epoch 28: saving model to models_tp_robust/1.31/model_tp_2_28.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.8199 - accuracy: 0.8036 - val_loss: 0.7919 - val_accuracy: 0.7500
# Epoch 29/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7940 - accuracy: 0.8304
# Epoch 29: saving model to models_tp_robust/1.31/model_tp_2_29.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.7940 - accuracy: 0.8304 - val_loss: 0.8575 - val_accuracy: 0.7500
# Epoch 30/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8321 - accuracy: 0.8170
# Epoch 30: saving model to models_tp_robust/1.31/model_tp_2_30.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.8321 - accuracy: 0.8170 - val_loss: 0.9063 - val_accuracy: 0.7500
# Epoch 31/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7839 - accuracy: 0.8527
# Epoch 31: saving model to models_tp_robust/1.31/model_tp_2_31.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.7839 - accuracy: 0.8527 - val_loss: 0.9122 - val_accuracy: 0.7500
# Epoch 32/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9020 - accuracy: 0.8259
# Epoch 32: saving model to models_tp_robust/1.31/model_tp_2_32.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.9020 - accuracy: 0.8259 - val_loss: 0.8938 - val_accuracy: 0.7500
# Epoch 33/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0124 - accuracy: 0.8348
# Epoch 33: saving model to models_tp_robust/1.31/model_tp_2_33.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 1.0124 - accuracy: 0.8348 - val_loss: 0.9074 - val_accuracy: 0.7500
# Epoch 34/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9350 - accuracy: 0.8304
# Epoch 34: saving model to models_tp_robust/1.31/model_tp_2_34.keras
# 7/7 [==============================] - 1s 140ms/step - loss: 0.9350 - accuracy: 0.8304 - val_loss: 0.9210 - val_accuracy: 0.7500
# Epoch 35/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8739 - accuracy: 0.8259
# Epoch 35: saving model to models_tp_robust/1.31/model_tp_2_35.keras
# 7/7 [==============================] - 1s 132ms/step - loss: 0.8739 - accuracy: 0.8259 - val_loss: 0.9134 - val_accuracy: 0.7500
# Epoch 36/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8738 - accuracy: 0.8348
# Epoch 36: saving model to models_tp_robust/1.31/model_tp_2_36.keras
# 7/7 [==============================] - 1s 138ms/step - loss: 0.8738 - accuracy: 0.8348 - val_loss: 0.9238 - val_accuracy: 0.7500
# Epoch 37/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9956 - accuracy: 0.8393
# Epoch 37: saving model to models_tp_robust/1.31/model_tp_2_37.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.9956 - accuracy: 0.8393 - val_loss: 0.9292 - val_accuracy: 0.7500
# Epoch 38/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7508 - accuracy: 0.8571
# Epoch 38: saving model to models_tp_robust/1.31/model_tp_2_38.keras
# 7/7 [==============================] - 1s 139ms/step - loss: 0.7508 - accuracy: 0.8571 - val_loss: 0.9469 - val_accuracy: 0.7500
# Epoch 39/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9313 - accuracy: 0.8214
# Epoch 39: saving model to models_tp_robust/1.31/model_tp_2_39.keras
# 7/7 [==============================] - 1s 139ms/step - loss: 0.9313 - accuracy: 0.8214 - val_loss: 0.9713 - val_accuracy: 0.7500
# Epoch 40/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0243 - accuracy: 0.8348
# Epoch 40: saving model to models_tp_robust/1.31/model_tp_2_40.keras
# 7/7 [==============================] - 1s 142ms/step - loss: 1.0243 - accuracy: 0.8348 - val_loss: 0.9773 - val_accuracy: 0.7500
# Epoch 41/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0114 - accuracy: 0.8259
# Epoch 41: saving model to models_tp_robust/1.31/model_tp_2_41.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 1.0114 - accuracy: 0.8259 - val_loss: 1.0049 - val_accuracy: 0.7500
# Epoch 42/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0860 - accuracy: 0.8170
# Epoch 42: saving model to models_tp_robust/1.31/model_tp_2_42.keras
# 7/7 [==============================] - 1s 139ms/step - loss: 1.0860 - accuracy: 0.8170 - val_loss: 0.9877 - val_accuracy: 0.7500
# Epoch 43/50
# 7/7 [==============================] - ETA: 0s - loss: 1.2445 - accuracy: 0.8393
# Epoch 43: saving model to models_tp_robust/1.31/model_tp_2_43.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 1.2445 - accuracy: 0.8393 - val_loss: 0.9659 - val_accuracy: 0.7500
# Epoch 44/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0397 - accuracy: 0.8304
# Epoch 44: saving model to models_tp_robust/1.31/model_tp_2_44.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 1.0397 - accuracy: 0.8304 - val_loss: 0.9815 - val_accuracy: 0.7500
# Epoch 45/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7896 - accuracy: 0.8571
# Epoch 45: saving model to models_tp_robust/1.31/model_tp_2_45.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.7896 - accuracy: 0.8571 - val_loss: 1.0275 - val_accuracy: 0.7500
# Epoch 46/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9941 - accuracy: 0.8259
# Epoch 46: saving model to models_tp_robust/1.31/model_tp_2_46.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.9941 - accuracy: 0.8259 - val_loss: 1.0379 - val_accuracy: 0.7500
# Epoch 47/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0811 - accuracy: 0.8348
# Epoch 47: saving model to models_tp_robust/1.31/model_tp_2_47.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 1.0811 - accuracy: 0.8348 - val_loss: 1.0221 - val_accuracy: 0.7500
# Epoch 48/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9549 - accuracy: 0.8259
# Epoch 48: saving model to models_tp_robust/1.31/model_tp_2_48.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.9549 - accuracy: 0.8259 - val_loss: 1.0381 - val_accuracy: 0.7500
# Epoch 49/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8959 - accuracy: 0.8527
# Epoch 49: saving model to models_tp_robust/1.31/model_tp_2_49.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.8959 - accuracy: 0.8527 - val_loss: 1.0592 - val_accuracy: 0.7500
# Epoch 50/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1402 - accuracy: 0.8080
# Epoch 50: saving model to models_tp_robust/1.31/model_tp_2_50.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 1.1402 - accuracy: 0.8080 - val_loss: 1.0183 - val_accuracy: 0.7500
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9663 - accuracy: 0.5312
# Epoch 1: saving model to models_tp_robust/1.31/model_tp_3_01.keras
# 7/7 [==============================] - 2s 144ms/step - loss: 0.9663 - accuracy: 0.5312 - val_loss: 0.7152 - val_accuracy: 0.5938
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0140 - accuracy: 0.5491
# Epoch 2: saving model to models_tp_robust/1.31/model_tp_3_02.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 1.0140 - accuracy: 0.5491 - val_loss: 0.6882 - val_accuracy: 0.6250
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0103 - accuracy: 0.5625
# Epoch 3: saving model to models_tp_robust/1.31/model_tp_3_03.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 1.0103 - accuracy: 0.5625 - val_loss: 0.6677 - val_accuracy: 0.6562
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9692 - accuracy: 0.6116
# Epoch 4: saving model to models_tp_robust/1.31/model_tp_3_04.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.9692 - accuracy: 0.6116 - val_loss: 0.6254 - val_accuracy: 0.6562
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0705 - accuracy: 0.5714
# Epoch 5: saving model to models_tp_robust/1.31/model_tp_3_05.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 1.0705 - accuracy: 0.5714 - val_loss: 0.6474 - val_accuracy: 0.7188
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0117 - accuracy: 0.6429
# Epoch 6: saving model to models_tp_robust/1.31/model_tp_3_06.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 1.0117 - accuracy: 0.6429 - val_loss: 0.6774 - val_accuracy: 0.7812
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9532 - accuracy: 0.6607
# Epoch 7: saving model to models_tp_robust/1.31/model_tp_3_07.keras
# 7/7 [==============================] - 1s 139ms/step - loss: 0.9532 - accuracy: 0.6607 - val_loss: 0.6995 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9459 - accuracy: 0.6339
# Epoch 8: saving model to models_tp_robust/1.31/model_tp_3_08.keras
# 7/7 [==============================] - 1s 142ms/step - loss: 0.9459 - accuracy: 0.6339 - val_loss: 0.7158 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9447 - accuracy: 0.6562
# Epoch 9: saving model to models_tp_robust/1.31/model_tp_3_09.keras
# 7/7 [==============================] - 1s 132ms/step - loss: 0.9447 - accuracy: 0.6562 - val_loss: 0.6873 - val_accuracy: 0.7812
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8603 - accuracy: 0.6652
# Epoch 10: saving model to models_tp_robust/1.31/model_tp_3_10.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.8603 - accuracy: 0.6652 - val_loss: 0.6480 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7755 - accuracy: 0.6830
# Epoch 11: saving model to models_tp_robust/1.31/model_tp_3_11.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.7755 - accuracy: 0.6830 - val_loss: 0.6340 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8081 - accuracy: 0.7188
# Epoch 12: saving model to models_tp_robust/1.31/model_tp_3_12.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.8081 - accuracy: 0.7188 - val_loss: 0.6309 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9562 - accuracy: 0.6920
# Epoch 13: saving model to models_tp_robust/1.31/model_tp_3_13.keras
# 7/7 [==============================] - 1s 141ms/step - loss: 0.9562 - accuracy: 0.6920 - val_loss: 0.6584 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9708 - accuracy: 0.7009
# Epoch 14: saving model to models_tp_robust/1.31/model_tp_3_14.keras
# 7/7 [==============================] - 1s 138ms/step - loss: 0.9708 - accuracy: 0.7009 - val_loss: 0.6856 - val_accuracy: 0.7812
# Epoch 15/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9998 - accuracy: 0.7188
# Epoch 15: saving model to models_tp_robust/1.31/model_tp_3_15.keras
# 7/7 [==============================] - 1s 140ms/step - loss: 0.9998 - accuracy: 0.7188 - val_loss: 0.7066 - val_accuracy: 0.7812
# Epoch 16/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7646 - accuracy: 0.7411
# Epoch 16: saving model to models_tp_robust/1.31/model_tp_3_16.keras
# ...
# Epoch 46/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9646 - accuracy: 0.8214
# Epoch 46: saving model to models_tp_robust/1.31/model_tp_48_46.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.9646 - accuracy: 0.8214 - val_loss: 1.4299 - val_accuracy: 0.7500
# Epoch 47/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7954 - accuracy: 0.8393
# Epoch 47: saving model to models_tp_robust/1.31/model_tp_48_47.keras
# 7/7 [==============================] - 1s 132ms/step - loss: 0.7954 - accuracy: 0.8393 - val_loss: 1.4242 - val_accuracy: 0.7812
# Epoch 48/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9881 - accuracy: 0.7946
# Epoch 48: saving model to models_tp_robust/1.31/model_tp_48_48.keras
# 7/7 [==============================] - 1s 142ms/step - loss: 0.9881 - accuracy: 0.7946 - val_loss: 1.3981 - val_accuracy: 0.7812
# Epoch 49/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1482 - accuracy: 0.8214
# Epoch 49: saving model to models_tp_robust/1.31/model_tp_48_49.keras
# 7/7 [==============================] - 1s 141ms/step - loss: 1.1482 - accuracy: 0.8214 - val_loss: 1.3860 - val_accuracy: 0.7812
# Epoch 50/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7743 - accuracy: 0.8482
# Epoch 50: saving model to models_tp_robust/1.31/model_tp_48_50.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.7743 - accuracy: 0.8482 - val_loss: 1.4155 - val_accuracy: 0.7812
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5914 - accuracy: 0.7589
# Epoch 1: saving model to models_tp_robust/1.31/model_tp_49_01.keras
# 7/7 [==============================] - 2s 145ms/step - loss: 0.5914 - accuracy: 0.7589 - val_loss: 0.6590 - val_accuracy: 0.7188
# Epoch 2/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5821 - accuracy: 0.7768
# Epoch 2: saving model to models_tp_robust/1.31/model_tp_49_02.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.5821 - accuracy: 0.7768 - val_loss: 0.7004 - val_accuracy: 0.7500
# Epoch 3/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5633 - accuracy: 0.7946
# Epoch 3: saving model to models_tp_robust/1.31/model_tp_49_03.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.5633 - accuracy: 0.7946 - val_loss: 0.7471 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5932 - accuracy: 0.8125
# Epoch 4: saving model to models_tp_robust/1.31/model_tp_49_04.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.5932 - accuracy: 0.8125 - val_loss: 0.7687 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6657 - accuracy: 0.7991
# Epoch 5: saving model to models_tp_robust/1.31/model_tp_49_05.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.6657 - accuracy: 0.7991 - val_loss: 0.7803 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5332 - accuracy: 0.8259
# Epoch 6: saving model to models_tp_robust/1.31/model_tp_49_06.keras
# 7/7 [==============================] - 1s 138ms/step - loss: 0.5332 - accuracy: 0.8259 - val_loss: 0.8264 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6203 - accuracy: 0.8304
# Epoch 7: saving model to models_tp_robust/1.31/model_tp_49_07.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.6203 - accuracy: 0.8304 - val_loss: 0.8751 - val_accuracy: 0.7812
# Epoch 8/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5732 - accuracy: 0.8259
# Epoch 8: saving model to models_tp_robust/1.31/model_tp_49_08.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.5732 - accuracy: 0.8259 - val_loss: 0.9176 - val_accuracy: 0.7812
# Epoch 9/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5868 - accuracy: 0.8527
# Epoch 9: saving model to models_tp_robust/1.31/model_tp_49_09.keras
# 7/7 [==============================] - 1s 131ms/step - loss: 0.5868 - accuracy: 0.8527 - val_loss: 0.9826 - val_accuracy: 0.7812
# Epoch 10/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5726 - accuracy: 0.8170
# Epoch 10: saving model to models_tp_robust/1.31/model_tp_49_10.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.5726 - accuracy: 0.8170 - val_loss: 1.0187 - val_accuracy: 0.7812
# Epoch 11/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5492 - accuracy: 0.8348
# Epoch 11: saving model to models_tp_robust/1.31/model_tp_49_11.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.5492 - accuracy: 0.8348 - val_loss: 1.0313 - val_accuracy: 0.7812
# Epoch 12/50
# 7/7 [==============================] - ETA: 0s - loss: 0.5483 - accuracy: 0.8616
# Epoch 12: saving model to models_tp_robust/1.31/model_tp_49_12.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.5483 - accuracy: 0.8616 - val_loss: 1.1005 - val_accuracy: 0.7812
# Epoch 13/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6094 - accuracy: 0.8571
# Epoch 13: saving model to models_tp_robust/1.31/model_tp_49_13.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.6094 - accuracy: 0.8571 - val_loss: 1.1551 - val_accuracy: 0.7812
# Epoch 14/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6955 - accuracy: 0.8616
# Epoch 14: saving model to models_tp_robust/1.31/model_tp_49_14.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.6955 - accuracy: 0.8616 - val_loss: 1.2164 - val_accuracy: 0.7812
# Epoch 15/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7915 - accuracy: 0.8393
# Epoch 15: saving model to models_tp_robust/1.31/model_tp_49_15.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.7915 - accuracy: 0.8393 - val_loss: 1.2408 - val_accuracy: 0.7812
# Epoch 16/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6476 - accuracy: 0.8839
# Epoch 16: saving model to models_tp_robust/1.31/model_tp_49_16.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.6476 - accuracy: 0.8839 - val_loss: 1.2751 - val_accuracy: 0.7812
# Epoch 17/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6555 - accuracy: 0.8571
# Epoch 17: saving model to models_tp_robust/1.31/model_tp_49_17.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.6555 - accuracy: 0.8571 - val_loss: 1.3226 - val_accuracy: 0.7812
# Epoch 18/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8269 - accuracy: 0.8705
# Epoch 18: saving model to models_tp_robust/1.31/model_tp_49_18.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.8269 - accuracy: 0.8705 - val_loss: 1.3654 - val_accuracy: 0.7812
# Epoch 19/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8802 - accuracy: 0.8571
# Epoch 19: saving model to models_tp_robust/1.31/model_tp_49_19.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.8802 - accuracy: 0.8571 - val_loss: 1.3842 - val_accuracy: 0.7812
# Epoch 20/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9002 - accuracy: 0.8750
# Epoch 20: saving model to models_tp_robust/1.31/model_tp_49_20.keras
# 7/7 [==============================] - 1s 132ms/step - loss: 0.9002 - accuracy: 0.8750 - val_loss: 1.4420 - val_accuracy: 0.7812
# Epoch 21/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8186 - accuracy: 0.8750
# Epoch 21: saving model to models_tp_robust/1.31/model_tp_49_21.keras
# 7/7 [==============================] - 1s 139ms/step - loss: 0.8186 - accuracy: 0.8750 - val_loss: 1.4745 - val_accuracy: 0.7812
# Epoch 22/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7796 - accuracy: 0.8571
# Epoch 22: saving model to models_tp_robust/1.31/model_tp_49_22.keras
# 7/7 [==============================] - 1s 142ms/step - loss: 0.7796 - accuracy: 0.8571 - val_loss: 1.5084 - val_accuracy: 0.7812
# Epoch 23/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9146 - accuracy: 0.8616
# Epoch 23: saving model to models_tp_robust/1.31/model_tp_49_23.keras
# 7/7 [==============================] - 1s 140ms/step - loss: 0.9146 - accuracy: 0.8616 - val_loss: 1.5342 - val_accuracy: 0.7812
# Epoch 24/50
# 7/7 [==============================] - ETA: 0s - loss: 0.6586 - accuracy: 0.8973
# Epoch 24: saving model to models_tp_robust/1.31/model_tp_49_24.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.6586 - accuracy: 0.8973 - val_loss: 1.5833 - val_accuracy: 0.7812
# Epoch 25/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8347 - accuracy: 0.8795
# Epoch 25: saving model to models_tp_robust/1.31/model_tp_49_25.keras
# 7/7 [==============================] - 1s 138ms/step - loss: 0.8347 - accuracy: 0.8795 - val_loss: 1.6129 - val_accuracy: 0.7812
# Epoch 26/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7859 - accuracy: 0.8973
# Epoch 26: saving model to models_tp_robust/1.31/model_tp_49_26.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.7859 - accuracy: 0.8973 - val_loss: 1.6325 - val_accuracy: 0.7812
# Epoch 27/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8931 - accuracy: 0.8795
# Epoch 27: saving model to models_tp_robust/1.31/model_tp_49_27.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.8931 - accuracy: 0.8795 - val_loss: 1.6405 - val_accuracy: 0.7812
# Epoch 28/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7720 - accuracy: 0.8527
# Epoch 28: saving model to models_tp_robust/1.31/model_tp_49_28.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 0.7720 - accuracy: 0.8527 - val_loss: 1.6507 - val_accuracy: 0.7812
# Epoch 29/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7476 - accuracy: 0.8750
# Epoch 29: saving model to models_tp_robust/1.31/model_tp_49_29.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.7476 - accuracy: 0.8750 - val_loss: 1.6430 - val_accuracy: 0.7812
# Epoch 30/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8214 - accuracy: 0.8884
# Epoch 30: saving model to models_tp_robust/1.31/model_tp_49_30.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.8214 - accuracy: 0.8884 - val_loss: 1.6483 - val_accuracy: 0.7812
# Epoch 31/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8053 - accuracy: 0.8705
# Epoch 31: saving model to models_tp_robust/1.31/model_tp_49_31.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.8053 - accuracy: 0.8705 - val_loss: 1.7082 - val_accuracy: 0.7812
# Epoch 32/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7793 - accuracy: 0.8884
# Epoch 32: saving model to models_tp_robust/1.31/model_tp_49_32.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.7793 - accuracy: 0.8884 - val_loss: 1.7685 - val_accuracy: 0.7812
# Epoch 33/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9825 - accuracy: 0.8750
# Epoch 33: saving model to models_tp_robust/1.31/model_tp_49_33.keras
# 7/7 [==============================] - 1s 144ms/step - loss: 0.9825 - accuracy: 0.8750 - val_loss: 1.8159 - val_accuracy: 0.7812
# Epoch 34/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9836 - accuracy: 0.8705
# Epoch 34: saving model to models_tp_robust/1.31/model_tp_49_34.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.9836 - accuracy: 0.8705 - val_loss: 1.8458 - val_accuracy: 0.7812
# Epoch 35/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9474 - accuracy: 0.8705
# Epoch 35: saving model to models_tp_robust/1.31/model_tp_49_35.keras
# 7/7 [==============================] - 1s 132ms/step - loss: 0.9474 - accuracy: 0.8705 - val_loss: 1.8744 - val_accuracy: 0.7812
# Epoch 36/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8208 - accuracy: 0.8750
# Epoch 36: saving model to models_tp_robust/1.31/model_tp_49_36.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 0.8208 - accuracy: 0.8750 - val_loss: 1.9087 - val_accuracy: 0.7812
# Epoch 37/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8978 - accuracy: 0.8884
# Epoch 37: saving model to models_tp_robust/1.31/model_tp_49_37.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 0.8978 - accuracy: 0.8884 - val_loss: 1.9257 - val_accuracy: 0.7812
# Epoch 38/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1734 - accuracy: 0.8616
# Epoch 38: saving model to models_tp_robust/1.31/model_tp_49_38.keras
# 7/7 [==============================] - 1s 135ms/step - loss: 1.1734 - accuracy: 0.8616 - val_loss: 1.9448 - val_accuracy: 0.7812
# Epoch 39/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7898 - accuracy: 0.9018
# Epoch 39: saving model to models_tp_robust/1.31/model_tp_49_39.keras
# 7/7 [==============================] - 1s 132ms/step - loss: 0.7898 - accuracy: 0.9018 - val_loss: 1.9414 - val_accuracy: 0.7812
# Epoch 40/50
# 7/7 [==============================] - ETA: 0s - loss: 1.1424 - accuracy: 0.8616
# Epoch 40: saving model to models_tp_robust/1.31/model_tp_49_40.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 1.1424 - accuracy: 0.8616 - val_loss: 1.9502 - val_accuracy: 0.7812
# Epoch 41/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0383 - accuracy: 0.8795
# Epoch 41: saving model to models_tp_robust/1.31/model_tp_49_41.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 1.0383 - accuracy: 0.8795 - val_loss: 1.9739 - val_accuracy: 0.7812
# Epoch 42/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0956 - accuracy: 0.8661
# Epoch 42: saving model to models_tp_robust/1.31/model_tp_49_42.keras
# 7/7 [==============================] - 1s 134ms/step - loss: 1.0956 - accuracy: 0.8661 - val_loss: 1.9942 - val_accuracy: 0.7812
# Epoch 43/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8399 - accuracy: 0.8795
# Epoch 43: saving model to models_tp_robust/1.31/model_tp_49_43.keras
# 7/7 [==============================] - 1s 142ms/step - loss: 0.8399 - accuracy: 0.8795 - val_loss: 2.0002 - val_accuracy: 0.7812
# Epoch 44/50
# 7/7 [==============================] - ETA: 0s - loss: 0.8991 - accuracy: 0.8839
# Epoch 44: saving model to models_tp_robust/1.31/model_tp_49_44.keras
# 7/7 [==============================] - 1s 144ms/step - loss: 0.8991 - accuracy: 0.8839 - val_loss: 2.0153 - val_accuracy: 0.7812
# Epoch 45/50
# 7/7 [==============================] - ETA: 0s - loss: 0.7625 - accuracy: 0.8973
# Epoch 45: saving model to models_tp_robust/1.31/model_tp_49_45.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.7625 - accuracy: 0.8973 - val_loss: 2.0180 - val_accuracy: 0.7812
# Epoch 46/50
# 7/7 [==============================] - ETA: 0s - loss: 1.2146 - accuracy: 0.8661
# Epoch 46: saving model to models_tp_robust/1.31/model_tp_49_46.keras
# 7/7 [==============================] - 1s 136ms/step - loss: 1.2146 - accuracy: 0.8661 - val_loss: 2.0334 - val_accuracy: 0.7812
# Epoch 47/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9814 - accuracy: 0.8884
# Epoch 47: saving model to models_tp_robust/1.31/model_tp_49_47.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.9814 - accuracy: 0.8884 - val_loss: 2.0998 - val_accuracy: 0.7812
# Epoch 48/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9659 - accuracy: 0.8884
# Epoch 48: saving model to models_tp_robust/1.31/model_tp_49_48.keras
# 7/7 [==============================] - 1s 137ms/step - loss: 0.9659 - accuracy: 0.8884 - val_loss: 2.1799 - val_accuracy: 0.7812
# Epoch 49/50
# 7/7 [==============================] - ETA: 0s - loss: 0.9878 - accuracy: 0.8795
# Epoch 49: saving model to models_tp_robust/1.31/model_tp_49_49.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 0.9878 - accuracy: 0.8795 - val_loss: 2.2453 - val_accuracy: 0.7812
# Epoch 50/50
# 7/7 [==============================] - ETA: 0s - loss: 1.0785 - accuracy: 0.8839
# Epoch 50: saving model to models_tp_robust/1.31/model_tp_49_50.keras
# 7/7 [==============================] - 1s 133ms/step - loss: 1.0785 - accuracy: 0.8839 - val_loss: 2.2939 - val_accuracy: 0.7812

# %% [markdown]
# STATS Scripts

# %%
f1_total = []
auc_total = []

for idx in range(len(noise_vals)):
    # Step 1: Load all CSVs into a list of DataFrames
    csv_files = glob.glob(f"tp_robust_log/{noise_vals[idx]}/training_log_tp_*.csv")
    histories = [pd.read_csv(f) for f in csv_files]
    
    # Step 2: Stack the metrics for each epoch
    metrics = ['loss', 'accuracy', 'val_loss', 'val_accuracy']
    avg_metrics = {m: [] for m in metrics}
    std_metrics = {m: [] for m in metrics}
    epochs = histories[0]['epoch']  # Assuming all runs have the same epoch range
    
    for epoch in epochs:
        for metric in metrics:
            values = [h.loc[epoch, metric] for h in histories]
            avg_metrics[metric].append(np.mean(values))
            std_metrics[metric].append(np.std(values))
    
    
    model_paths = glob.glob(f"models_tp_robust/{noise_vals[idx]}/model_tp_*_50.keras")
    model_paths.sort()
    
    tp_list = []
    fp_list = []
    tn_list = []
    fn_list = []
    f1_scores = []
    auc_scores = []
    
    
    for index, model_path in enumerate(model_paths):
        model = tf.keras.models.load_model(model_path, compile=False)
        y_pred_prob = model.predict(datasets[0][1])
        y_pred = (y_pred_prob > 0.5).astype(int)
    
        f1 = f1_score(datasets[0][3], y_pred)
        auc = roc_auc_score(datasets[0][3], y_pred_prob)
        
        f1_scores.append(f1)
        auc_scores.append(auc)
        
        tn, fp, fn, tp = confusion_matrix(datasets[0][3], y_pred).ravel()
        
        tp_list.append(tp)
        fp_list.append(fp)
        tn_list.append(tn)
        fn_list.append(fn)
        
    # Compute mean and SE for each confusion matrix component
    tp_mean, tp_se = mean_se(tp_list)
    fp_mean, fp_se = mean_se(fp_list)
    tn_mean, tn_se = mean_se(tn_list)
    fn_mean, fn_se = mean_se(fn_list)
    
    # Construct the matrix and annotation array
    conf_matrix = np.array([[tn_mean, fp_mean],
                            [fn_mean, tp_mean]])
    
    annotations = np.array([[f"{tn_mean:.1f}\n±{tn_se:.1f}", f"{fp_mean:.1f}\n±{fp_se:.1f}"],
                            [f"{fn_mean:.1f}\n±{fn_se:.1f}", f"{tp_mean:.1f}\n±{tp_se:.1f}"]])

    f1_total.append(mean_se(f1_scores))
    auc_total.append(mean_se(auc_scores))

    plot_metric_distribution(f1_scores, "F1 Score", "f1_score_robust", epsilons)
    plot_metric_distribution(auc_scores, "AUC Score", "AUC_score_robust", epsilons)
    plot_confusion_matrix_with_se(conf_matrix, annotations, epsilons)
    plot_avg_history(epochs, avg_metrics, std_metrics, epsilons)
# Out:
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step

# %%
f1_baseline = (0.9659922307568748, 0.002160392362343558)
auc_baseline = (0.896936507936508, 0.00458851871947309)

# %%
plot_mean_se_with_baseline(f1_total, epsilons, "epsilons", "Average F1 Score", "avg_f1",
                                f1_baseline, baseline_label="baseline")
# Out:
# /tmp/ipykernel_18977/978787756.py:18: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.errorbar(x_ticks, means, yerr=ses, fmt='o-', capsize=5,

# %%
plot_mean_se_with_baseline(auc_total, epsilons, "epsilons", "Average AUC Score", "avg_auc",
                                auc_baseline, baseline_label="baseline")
# Out:
# /tmp/ipykernel_18977/978787756.py:18: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   plt.errorbar(x_ticks, means, yerr=ses, fmt='o-', capsize=5,
